# %% [markdown]
# # StarDist for counting Cell Nuclei From Fluorescence Imaging
# ## Introduction
#
# This script is meant to:
#
# 1. Iterate all files in a provided directory,
# 2. First perform cell counting on DAPI images and output a file `parameter-timepoint-DAPI.out`
# 3. Then perform cell counting on FITC images and output a fle `parameter-timepoint-FITC.out`
# 4. Add the FITC output to the DAPI output, compute the fractional cell viability, then save as `viability-parameter.csv`

# %% [markdown]
# ## Parameters Needed
#
# **This notebook assumes that each experimental group is isolated by directory.**
#
# **If isolated by filename, please make sure file names are semantic.**
#
# + Directory of images to be analyzed **Ensure that each image files has _DAPI.tif or _FITC.tif as a suffix**
# + Parameter name, i.e. what is being examined
# + If this consists of multiple time points, the time point

# %% [markdown]
# ## Step One: Initialize Requisite Libraries
#
# This makes sure that libraries required for StarDist are loaded. Tensorflow may ask to rebuild for AVX instructions, this is not necessary.

# %%
from stardist.models import StarDist2D
from stardist.data import test_image_nuclei_2d
from stardist.plot import render_label
from csbdeep.utils import normalize
import matplotlib.pyplot as plt
from skimage.segmentation import find_boundaries
from tifffile import imread
from skimage.color import label2rgb
import os
from glob import glob
import pandas as pd  

data = [] # initialize empty data frame
# Out:
# 2025-01-26 20:26:22.997523: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Step Two: Load StarDist 2D Fluorescence Training Set
#
# StarDist is trained on the following datasets
#
# + 2D nuclear fluoresence
# + 2D Hematoxylin and Eosin (H&E) histological sections
# + 3D nuclear fluoresence
#
# You need to initialize the training data you need for proper function, as shown here

# %%
model = StarDist2D.from_pretrained('2D_versatile_fluo') # 2D Nuclei Fluorescence
# Out:
# Found model '2D_versatile_fluo' for 'StarDist2D'.
# Loading network weights from 'weights_best.h5'.
# Loading thresholds from 'thresholds.json'.
# Using default values: prob_thresh=0.479071, nms_thresh=0.3.
# 2025-01-26 20:26:59.718382: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %% [markdown]
# ## Step Three: Specify Your Parameters
#
# First, specify the directory you have your image files at, an example is
#
# `imageDirectory = os.path.expanduser("/home/woodn/Desktop/viability/images/")`

# %%
imageDirectory = os.path.expanduser("<directory/here>")
saveDirectory = os.path.expanduser(imageDirectory)

# %% [markdown]
# Now enter what this image set represents
#
# An example would be:
#
# `experimentalGroup1`
#
# Replace white space with characters such as -,_,., or use camelCaseLikeThis

# %%
setName = '<enter_set_name_here>'

# %% [markdown]
# If needed, designate a time point, otherwise, keep it as `na`

# %%
timePoint = 'na'

# %% [markdown]
# ## Step Four: Run StarDist on DAPI Files
#
# The below command will read all DAPI files.
#
# Please make sure that
#
# + You specify a new directory for each experimental group, otherwise, you are executing for the same group again and again
# + Specify experimental group name
# + Specify time point if used

# %%
dapiout = f'{setName}-{timePoint}-DAPI.out'
saveReadsCSV = os.path.join(saveDirectory,dapiout)
dapi = []
for img in sorted(glob(os.path.join(imageDirectory,"*_DAPI.tif"))):
    image = imread(img)
    image = normalize(image,1,99.8)         # NORMALIZE FLUOR INTENSITY
    labels, cells = model.predict_instances(image,
        scale=1,
        return_labels=True)             # THIS IS THE MODEL 
    probability = list(cells["prob"])
    n_detections = len(probability)     # THE LENGTH OF PROBABILITY VECTOR IS THE CELL COUNT
    print('\n')
    print(f'{img},{setName},{timePoint},{n_detections}')     # PRINTS OUT EACH ITERATED FILE
    dapi.append([timePoint,setName,img, n_detections])    # STORE CELL COUNT WITH FILE NAME
# Out:
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1385
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph3-day02.tif,<enter_set_name_here>,na,686
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1381
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph3-day04.tif,<enter_set_name_here>,na,2204
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph3-day05.tif,<enter_set_name_here>,na,1729
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1390
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1611
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2187
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2422
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph5-day05.tif,<enter_set_name_here>,na,2714
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1523
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph6-day02.tif,<enter_set_name_here>,na,1634
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2550
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2414
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph6-day05.tif,<enter_set_name_here>,na,3030
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph7-day01.tif,<enter_set_name_here>,na,1278
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph7-day02.tif,<enter_set_name_here>,na,1755
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2044
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2457
#
#
# /home/woodn/Desktop/viabilityph/DAPI/01_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2769
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1453
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph3-day02.tif,<enter_set_name_here>,na,1393
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1516
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph3-day04.tif,<enter_set_name_here>,na,1994
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph3-day05.tif,<enter_set_name_here>,na,2205
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1360
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1725
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2184
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2473
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph5-day05.tif,<enter_set_name_here>,na,2954
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1677
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph6-day02.tif,<enter_set_name_here>,na,1568
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2039
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2371
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph6-day05.tif,<enter_set_name_here>,na,3125
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph7-day01.tif,<enter_set_name_here>,na,1455
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph7-day02.tif,<enter_set_name_here>,na,2115
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2143
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2528
#
#
# /home/woodn/Desktop/viabilityph/DAPI/02_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2510
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1425
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph3-day02.tif,<enter_set_name_here>,na,1477
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1479
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph3-day04.tif,<enter_set_name_here>,na,1590
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph3-day05.tif,<enter_set_name_here>,na,2305
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1452
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1827
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2215
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2308
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph5-day05.tif,<enter_set_name_here>,na,2822
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1646
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph6-day02.tif,<enter_set_name_here>,na,1436
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2392
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2608
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph6-day05.tif,<enter_set_name_here>,na,3187
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph7-day01.tif,<enter_set_name_here>,na,1303
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph7-day02.tif,<enter_set_name_here>,na,2105
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2409
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2062
#
#
# /home/woodn/Desktop/viabilityph/DAPI/03_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2898
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1325
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph3-day02.tif,<enter_set_name_here>,na,1022
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1357
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph3-day04.tif,<enter_set_name_here>,na,1759
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph3-day05.tif,<enter_set_name_here>,na,2328
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1393
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1396
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2307
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2458
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph5-day05.tif,<enter_set_name_here>,na,3276
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1403
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph6-day02.tif,<enter_set_name_here>,na,2143
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2297
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2532
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph6-day05.tif,<enter_set_name_here>,na,2893
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph7-day01.tif,<enter_set_name_here>,na,1331
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph7-day02.tif,<enter_set_name_here>,na,2082
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2270
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph7-day04.tif,<enter_set_name_here>,na,1989
#
#
# /home/woodn/Desktop/viabilityph/DAPI/04_DAPI-ph7-day05.tif,<enter_set_name_here>,na,3104
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1265
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph3-day02.tif,<enter_set_name_here>,na,906
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1236
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph3-day04.tif,<enter_set_name_here>,na,1759
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph3-day05.tif,<enter_set_name_here>,na,2149
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1554
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1685
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2337
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2196
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph5-day05.tif,<enter_set_name_here>,na,2899
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1724
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph6-day02.tif,<enter_set_name_here>,na,1888
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2109
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2613
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph6-day05.tif,<enter_set_name_here>,na,3100
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph7-day01.tif,<enter_set_name_here>,na,2397
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph7-day02.tif,<enter_set_name_here>,na,1427
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2373
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2401
#
#
# /home/woodn/Desktop/viabilityph/DAPI/05_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2458
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1218
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph3-day02.tif,<enter_set_name_here>,na,979
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph3-day03.tif,<enter_set_name_here>,na,478
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph3-day04.tif,<enter_set_name_here>,na,1916
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph3-day05.tif,<enter_set_name_here>,na,2312
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1486
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1522
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2433
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2578
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph5-day05.tif,<enter_set_name_here>,na,2962
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1452
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph6-day02.tif,<enter_set_name_here>,na,2007
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2135
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2596
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph6-day05.tif,<enter_set_name_here>,na,2874
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph7-day01.tif,<enter_set_name_here>,na,1216
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph7-day02.tif,<enter_set_name_here>,na,1143
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2236
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2065
#
#
# /home/woodn/Desktop/viabilityph/DAPI/06_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2570
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1189
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph3-day02.tif,<enter_set_name_here>,na,1069
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1125
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph3-day04.tif,<enter_set_name_here>,na,2020
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph3-day05.tif,<enter_set_name_here>,na,2057
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1524
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1536
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2216
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2562
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph5-day05.tif,<enter_set_name_here>,na,3311
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph6-day01.tif,<enter_set_name_here>,na,961
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph6-day02.tif,<enter_set_name_here>,na,1532
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2021
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2518
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph6-day05.tif,<enter_set_name_here>,na,2872
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph7-day01.tif,<enter_set_name_here>,na,1448
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph7-day02.tif,<enter_set_name_here>,na,1177
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph7-day03.tif,<enter_set_name_here>,na,1832
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2259
#
#
# /home/woodn/Desktop/viabilityph/DAPI/07_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2429
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1298
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph3-day02.tif,<enter_set_name_here>,na,828
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1275
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph3-day04.tif,<enter_set_name_here>,na,1968
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph3-day05.tif,<enter_set_name_here>,na,2041
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1726
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1763
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2028
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2595
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph5-day05.tif,<enter_set_name_here>,na,2617
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1890
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph6-day02.tif,<enter_set_name_here>,na,1614
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph6-day03.tif,<enter_set_name_here>,na,1650
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2713
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph6-day05.tif,<enter_set_name_here>,na,2875
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph7-day01.tif,<enter_set_name_here>,na,1020
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph7-day02.tif,<enter_set_name_here>,na,1080
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2007
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2476
#
#
# /home/woodn/Desktop/viabilityph/DAPI/08_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2250
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1620
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph3-day02.tif,<enter_set_name_here>,na,1092
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1618
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph3-day04.tif,<enter_set_name_here>,na,2078
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph3-day05.tif,<enter_set_name_here>,na,1491
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1563
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph5-day02.tif,<enter_set_name_here>,na,2020
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph5-day03.tif,<enter_set_name_here>,na,1971
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2446
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph5-day05.tif,<enter_set_name_here>,na,2423
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1458
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph6-day02.tif,<enter_set_name_here>,na,1419
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2384
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2656
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph6-day05.tif,<enter_set_name_here>,na,3300
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph7-day01.tif,<enter_set_name_here>,na,2029
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph7-day02.tif,<enter_set_name_here>,na,1857
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2499
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2369
#
#
# /home/woodn/Desktop/viabilityph/DAPI/09_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2929
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1762
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph3-day02.tif,<enter_set_name_here>,na,1382
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1842
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph3-day04.tif,<enter_set_name_here>,na,2054
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph3-day05.tif,<enter_set_name_here>,na,1711
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1660
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1660
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph5-day03.tif,<enter_set_name_here>,na,1756
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2801
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph5-day05.tif,<enter_set_name_here>,na,2621
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph6-day01.tif,<enter_set_name_here>,na,2012
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph6-day02.tif,<enter_set_name_here>,na,1539
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2332
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2749
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph6-day05.tif,<enter_set_name_here>,na,2838
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph7-day01.tif,<enter_set_name_here>,na,1702
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph7-day02.tif,<enter_set_name_here>,na,926
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2673
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2435
#
#
# /home/woodn/Desktop/viabilityph/DAPI/10_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2596
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1662
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph3-day02.tif,<enter_set_name_here>,na,1319
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1303
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph3-day05.tif,<enter_set_name_here>,na,1905
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1490
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph5-day02.tif,<enter_set_name_here>,na,2037
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2042
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2689
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph5-day05.tif,<enter_set_name_here>,na,3272
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1208
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph6-day02.tif,<enter_set_name_here>,na,2399
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2746
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2550
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph6-day05.tif,<enter_set_name_here>,na,2553
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph7-day01.tif,<enter_set_name_here>,na,1174
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph7-day02.tif,<enter_set_name_here>,na,2443
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2270
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2670
#
#
# /home/woodn/Desktop/viabilityph/DAPI/11_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2996
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1493
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph3-day02.tif,<enter_set_name_here>,na,1138
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1678
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph3-day04.tif,<enter_set_name_here>,na,2072
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph3-day05.tif,<enter_set_name_here>,na,1840
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1613
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1919
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2365
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2370
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph5-day05.tif,<enter_set_name_here>,na,2634
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1504
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph6-day02.tif,<enter_set_name_here>,na,2130
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2600
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2579
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph6-day05.tif,<enter_set_name_here>,na,2723
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph7-day01.tif,<enter_set_name_here>,na,1931
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph7-day02.tif,<enter_set_name_here>,na,1488
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2742
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2701
#
#
# /home/woodn/Desktop/viabilityph/DAPI/12_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2900
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1407
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph3-day02.tif,<enter_set_name_here>,na,1541
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1776
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph3-day04.tif,<enter_set_name_here>,na,2011
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph3-day05.tif,<enter_set_name_here>,na,2149
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1766
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1794
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2349
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2230
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph5-day05.tif,<enter_set_name_here>,na,2711
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1288
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph6-day02.tif,<enter_set_name_here>,na,2180
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2463
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2595
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph6-day05.tif,<enter_set_name_here>,na,3055
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph7-day01.tif,<enter_set_name_here>,na,1043
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph7-day02.tif,<enter_set_name_here>,na,1882
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2662
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2653
#
#
# /home/woodn/Desktop/viabilityph/DAPI/13_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2794
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1427
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph3-day02.tif,<enter_set_name_here>,na,665
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1793
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph3-day04.tif,<enter_set_name_here>,na,1739
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph3-day05.tif,<enter_set_name_here>,na,2001
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph5-day01.tif,<enter_set_name_here>,na,919
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph5-day02.tif,<enter_set_name_here>,na,2025
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2340
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2435
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph5-day05.tif,<enter_set_name_here>,na,2383
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1459
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph6-day02.tif,<enter_set_name_here>,na,1655
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2205
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2659
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph6-day05.tif,<enter_set_name_here>,na,2790
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph7-day01.tif,<enter_set_name_here>,na,1843
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph7-day02.tif,<enter_set_name_here>,na,2229
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2579
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2298
#
#
# /home/woodn/Desktop/viabilityph/DAPI/14_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2624
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1258
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph3-day02.tif,<enter_set_name_here>,na,1054
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1944
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph3-day04.tif,<enter_set_name_here>,na,2082
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph3-day05.tif,<enter_set_name_here>,na,1995
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1175
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1910
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2080
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2348
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph5-day05.tif,<enter_set_name_here>,na,2068
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1627
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph6-day02.tif,<enter_set_name_here>,na,1966
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2346
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2761
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph6-day05.tif,<enter_set_name_here>,na,3237
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph7-day01.tif,<enter_set_name_here>,na,774
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph7-day02.tif,<enter_set_name_here>,na,2315
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2560
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2568
#
#
# /home/woodn/Desktop/viabilityph/DAPI/15_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2914
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph3-day01.tif,<enter_set_name_here>,na,767
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph3-day02.tif,<enter_set_name_here>,na,1174
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1681
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph3-day04.tif,<enter_set_name_here>,na,2001
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph3-day05.tif,<enter_set_name_here>,na,1628
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1937
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1724
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2253
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2513
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph5-day05.tif,<enter_set_name_here>,na,2663
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1689
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph6-day02.tif,<enter_set_name_here>,na,2048
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2610
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2637
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph6-day05.tif,<enter_set_name_here>,na,3341
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph7-day01.tif,<enter_set_name_here>,na,931
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph7-day02.tif,<enter_set_name_here>,na,1992
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2434
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2371
#
#
# /home/woodn/Desktop/viabilityph/DAPI/16_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2432
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1272
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph3-day02.tif,<enter_set_name_here>,na,1556
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph3-day03.tif,<enter_set_name_here>,na,2020
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph3-day04.tif,<enter_set_name_here>,na,1731
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph3-day05.tif,<enter_set_name_here>,na,2741
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1078
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1135
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph5-day03.tif,<enter_set_name_here>,na,1871
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2403
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph5-day05.tif,<enter_set_name_here>,na,3323
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1410
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph6-day02.tif,<enter_set_name_here>,na,1204
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2559
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2231
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph6-day05.tif,<enter_set_name_here>,na,2644
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph7-day01.tif,<enter_set_name_here>,na,1273
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph7-day02.tif,<enter_set_name_here>,na,1755
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2607
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2906
#
#
# /home/woodn/Desktop/viabilityph/DAPI/17_DAPI-ph7-day05.tif,<enter_set_name_here>,na,3121
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1592
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph3-day02.tif,<enter_set_name_here>,na,1893
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph3-day03.tif,<enter_set_name_here>,na,2107
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph3-day04.tif,<enter_set_name_here>,na,1845
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph3-day05.tif,<enter_set_name_here>,na,2157
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1412
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1972
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2649
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2383
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph5-day05.tif,<enter_set_name_here>,na,3207
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1064
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph6-day02.tif,<enter_set_name_here>,na,1908
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph6-day03.tif,<enter_set_name_here>,na,3149
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2164
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph6-day05.tif,<enter_set_name_here>,na,2648
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph7-day01.tif,<enter_set_name_here>,na,1460
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph7-day02.tif,<enter_set_name_here>,na,1561
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2522
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph7-day04.tif,<enter_set_name_here>,na,3040
#
#
# /home/woodn/Desktop/viabilityph/DAPI/18_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2772
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1382
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph3-day02.tif,<enter_set_name_here>,na,1440
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1705
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph3-day04.tif,<enter_set_name_here>,na,1105
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph3-day05.tif,<enter_set_name_here>,na,2135
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1151
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1942
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2365
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2734
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph5-day05.tif,<enter_set_name_here>,na,3279
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1952
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph6-day02.tif,<enter_set_name_here>,na,1556
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph6-day03.tif,<enter_set_name_here>,na,3247
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2368
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph6-day05.tif,<enter_set_name_here>,na,2448
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph7-day01.tif,<enter_set_name_here>,na,2019
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph7-day02.tif,<enter_set_name_here>,na,1682
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2709
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph7-day04.tif,<enter_set_name_here>,na,3121
#
#
# /home/woodn/Desktop/viabilityph/DAPI/19_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2662
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1211
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph3-day02.tif,<enter_set_name_here>,na,1360
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1742
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph3-day04.tif,<enter_set_name_here>,na,815
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph3-day05.tif,<enter_set_name_here>,na,2340
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1124
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1723
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2364
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2432
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph5-day05.tif,<enter_set_name_here>,na,3055
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1357
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph6-day02.tif,<enter_set_name_here>,na,2014
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2916
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2202
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph6-day05.tif,<enter_set_name_here>,na,2637
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph7-day01.tif,<enter_set_name_here>,na,726
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph7-day02.tif,<enter_set_name_here>,na,2508
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2623
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2508
#
#
# /home/woodn/Desktop/viabilityph/DAPI/20_DAPI-ph7-day05.tif,<enter_set_name_here>,na,3180
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1373
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph3-day02.tif,<enter_set_name_here>,na,1164
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1463
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph3-day04.tif,<enter_set_name_here>,na,1653
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph3-day05.tif,<enter_set_name_here>,na,1764
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1008
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1834
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2310
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2432
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph5-day05.tif,<enter_set_name_here>,na,3728
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph6-day01.tif,<enter_set_name_here>,na,2029
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph6-day02.tif,<enter_set_name_here>,na,1706
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2514
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2456
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph6-day05.tif,<enter_set_name_here>,na,2620
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph7-day01.tif,<enter_set_name_here>,na,1373
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph7-day02.tif,<enter_set_name_here>,na,2771
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2059
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2819
#
#
# /home/woodn/Desktop/viabilityph/DAPI/21_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2318
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1307
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1724
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph3-day04.tif,<enter_set_name_here>,na,1574
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph3-day05.tif,<enter_set_name_here>,na,1859
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph5-day01.tif,<enter_set_name_here>,na,804
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1618
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2167
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2413
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph5-day05.tif,<enter_set_name_here>,na,2789
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1872
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph6-day02.tif,<enter_set_name_here>,na,1861
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2857
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2164
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph6-day05.tif,<enter_set_name_here>,na,2158
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph7-day01.tif,<enter_set_name_here>,na,1465
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph7-day02.tif,<enter_set_name_here>,na,2276
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2307
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2862
#
#
# /home/woodn/Desktop/viabilityph/DAPI/22_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2363
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1394
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph3-day02.tif,<enter_set_name_here>,na,1258
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1687
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph3-day04.tif,<enter_set_name_here>,na,1341
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph3-day05.tif,<enter_set_name_here>,na,2003
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1289
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph5-day02.tif,<enter_set_name_here>,na,953
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph5-day03.tif,<enter_set_name_here>,na,2031
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2363
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph5-day05.tif,<enter_set_name_here>,na,3134
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph6-day01.tif,<enter_set_name_here>,na,1202
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph6-day02.tif,<enter_set_name_here>,na,1882
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2697
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2129
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph6-day05.tif,<enter_set_name_here>,na,2358
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph7-day01.tif,<enter_set_name_here>,na,1235
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph7-day02.tif,<enter_set_name_here>,na,1227
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph7-day03.tif,<enter_set_name_here>,na,2406
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2577
#
#
# /home/woodn/Desktop/viabilityph/DAPI/23_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2545
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph3-day01.tif,<enter_set_name_here>,na,1585
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph3-day02.tif,<enter_set_name_here>,na,1298
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph3-day03.tif,<enter_set_name_here>,na,1184
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph3-day04.tif,<enter_set_name_here>,na,1283
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph3-day05.tif,<enter_set_name_here>,na,1753
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph5-day01.tif,<enter_set_name_here>,na,1065
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph5-day02.tif,<enter_set_name_here>,na,1415
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph5-day03.tif,<enter_set_name_here>,na,1752
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph5-day04.tif,<enter_set_name_here>,na,2353
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph5-day05.tif,<enter_set_name_here>,na,3058
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph6-day01.tif,<enter_set_name_here>,na,879
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph6-day02.tif,<enter_set_name_here>,na,1034
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph6-day03.tif,<enter_set_name_here>,na,2621
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph6-day04.tif,<enter_set_name_here>,na,2191
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph6-day05.tif,<enter_set_name_here>,na,2759
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph7-day01.tif,<enter_set_name_here>,na,1425
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph7-day02.tif,<enter_set_name_here>,na,1425
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph7-day03.tif,<enter_set_name_here>,na,1965
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph7-day04.tif,<enter_set_name_here>,na,2915
#
#
# /home/woodn/Desktop/viabilityph/DAPI/24_DAPI-ph7-day05.tif,<enter_set_name_here>,na,2173

# %% [markdown]
# Now save your DAPI data

# %%
dataFrame = pd.DataFrame(dapi, columns = ["timePoint","setName","FILENAME","COUNT"])
dataFrame.to_csv(saveReadsCSV, sep='\t', encoding='utf-8')

# %% [markdown]
# ## Step Five: Run StarDist on FITC Files
#
# This performs the same function as StarDist on DAPI, but now on FITC channel images

# %%
fitcout = f'{setName}-{timePoint}-FITC.out'
saveReadsCSV = os.path.join(saveDirectory,fitcout)
fitc = []
for img in sorted(glob(os.path.join(imageDirectory,"*_FITC.tif"))):
    image = imread(img)
    image = normalize(image,1,99.8)         # NORMALIZE FLUOR INTENSITY
    labels, cells = model.predict_instances(image,
        scale=1,
        return_labels=True)             # THIS IS THE MODEL 
    probability = list(cells["prob"])
    n_detections = len(probability)     # THE LENGTH OF PROBABILITY VECTOR IS THE CELL COUNT
    print('\n')
    print(f'{img},{setName},{timePoint},{n_detections}')     # PRINTS OUT EACH ITERATED FILE
    fitc.append([timePoint,setName,img, n_detections])    # STORE CELL COUNT WITH FILE NAME

# %% [markdown]
# Now save your FITC data !

# %%
dataFrame = pd.DataFrame(fitc, columns = ["timePoint","setName","FILENAME","COUNT"])
dataFrame.to_csv(saveReadsCSV, sep='\t', encoding='utf-8')

# %% [markdown]
# ## Outcome
#
# You should have
#
# + 2 CSV files, one for each fluoresence channel, in the specified output directory, which by default is the input directory
